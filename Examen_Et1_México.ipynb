# %% [markdown]
# <a href="https://colab.research.google.com/github/caroSF1/Evaluaci-n/blob/main/Examen_Et1_M%C3%A9xico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Evaluación**
# ## **Carolina Solis Flores**
# ## **A01708072**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3d84bad2-337a-42d9-a489-6d5f41e4b149" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d84bad2-337a-42d9-a489-6d5f41e4b149">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo .csv sin indice
df=pd.read_csv("DF_Mexico.csv")

# %% [markdown]
# ## **Etapa 1: Preprocesamientos de datos**

# %% [markdown]
# **Valores Nulos**

# %%
df.head(2)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  2056638  https://www.airbnb.com/rooms/2056638  20230329041210   2023-03-30
# 1  2072354  https://www.airbnb.com/rooms/2072354  20230329041210   2023-03-30
#
#         source                                name  \
# 0  city scrape  Amplio y luminoso loft en Coyoacán
# 1  city scrape  Coyoacan Historic Studio Apartment
#
#                                          description  \
# 0  Cómodo loft de dos pisos magníficamente ubicad...
# 1  This studio flat is adjacent to the owner's ho...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Located in Coyoacan, in a quiet neighborhood w...
#
#                                          picture_url   host_id  ...  \
# 0  https://a0.muscache.com/pictures/28353712/4379...  10531228  ...
# 1  https://a0.muscache.com/pictures/369f3371-593a...  16840050  ...
#
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3596
# Length: 75, dtype: int64

# %%
dfnum = df.select_dtypes(include = ["number"])
dfobj = df.select_dtypes(include = ["object"])

# %%
valores_nulos=dfnum.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# scrape_id                                           0
# host_id                                             0
# host_listings_count                                 0
# host_total_listings_count                           0
# neighbourhood_group_cleansed                    24224
# latitude                                            0
# longitude                                           0
# accommodates                                        0
# bathrooms                                       24224
# bedrooms                                          555
# beds                                              271
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              1
# maximum_minimum_nights                              1
# minimum_maximum_nights                              1
# ...

# %%
#Se sustituye los valores por el promedio pues medida de tendencia central más utilizada y nos permite tener un termino medio de los datos
dfnum=dfnum.fillna(round(dfnum.mean(),1))
dfnum
# Out:
#                        id       scrape_id    host_id  host_listings_count  \
# 0                 2056638  20230329041210   10531228                    3
# 1                 2072354  20230329041210   16840050                    3
# 2                  696037  20230329041210    3531879                    4
# 3                   35797  20230329041210     153786                    1
# 4                   44616  20230329041210     196253                   16
# ...                   ...             ...        ...                  ...
# 24219  853923589855678923  20230329041210  488030249                    3
# 24220  853966732274073000  20230329041210  506816029                    1
# 24221  854225071295768399  20230329041210  154670560                    1
# 24222  854247693069190865  20230329041210    7799414                   13
# 24223  854260329845513725  20230329041210  506864314                    2
#
#        host_total_listings_count  neighbourhood_group_cleansed   latitude  \
# ...

# %%
valores_nulos=dfnum.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# scrape_id                                           0
# host_id                                             0
# host_listings_count                                 0
# host_total_listings_count                           0
# neighbourhood_group_cleansed                    24224
# latitude                                            0
# longitude                                           0
# accommodates                                        0
# bathrooms                                       24224
# bedrooms                                            0
# beds                                                0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# ...

# %%
#Se utilizo un dropna ya que al hacer la sustitución de variables con promedio seguian apareciendo datos, esto es debido a que los datos de estas columnas estaban en ceros.
dfnum= dfnum.dropna(axis=1, how='all')

# %%
valores_nulos=dfnum.isnull().sum()
valores_nulos
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# ...

# %%
valores_nulos=dfobj.isnull().sum()
valores_nulos
# Out:
# listing_url                   0
# last_scraped                  0
# source                        0
# name                          1
# description                 928
# neighborhood_overview      9079
# picture_url                   0
# host_url                      0
# host_name                     0
# host_since                    0
# host_location              5172
# host_about                10664
# host_response_time         3091
# host_response_rate         3091
# host_acceptance_rate       2043
# host_is_superhost             5
# host_thumbnail_url            0
# host_picture_url              0
# host_neighbourhood        12401
# host_verifications            0
# host_has_profile_pic          0
# host_identity_verified        0
# neighbourhood              9079
# neighbourhood_cleansed        0
# property_type                 0
# room_type                     0
# bathrooms_text               30
# amenities                     0
# price                         0
# ...

# %%
#Se utilizará el método ffill, dado que sustituye los valores nulos por valores no nulos hacia adelante
dfobj= dfobj.fillna(method="ffill")

# %%
valores_nulos=dfobj.isnull().sum()
valores_nulos
# Out:
# listing_url               0
# last_scraped              0
# source                    0
# name                      0
# description               0
# neighborhood_overview     1
# picture_url               0
# host_url                  0
# host_name                 0
# host_since                0
# host_location             0
# host_about                2
# host_response_time        0
# host_response_rate        0
# host_acceptance_rate      2
# host_is_superhost         0
# host_thumbnail_url        0
# host_picture_url          0
# host_neighbourhood        0
# host_verifications        0
# host_has_profile_pic      0
# host_identity_verified    0
# neighbourhood             1
# neighbourhood_cleansed    0
# property_type             0
# room_type                 0
# bathrooms_text            0
# amenities                 0
# price                     0
# has_availability          0
# calendar_last_scraped     0
# first_review              0
# last_review               0
# ...

# %%
#Con el uso de ffill no se eliminaron todos los datos nulos, es por eso que se decidió utilizar bfill sustituye los valores nulos por valores no nulos hacia atrás.
dfobj= dfobj.fillna(method="bfill")

# %%
valores_nulos=dfobj.isnull().sum()
valores_nulos
# Out:
# listing_url               0
# last_scraped              0
# source                    0
# name                      0
# description               0
# neighborhood_overview     0
# picture_url               0
# host_url                  0
# host_name                 0
# host_since                0
# host_location             0
# host_about                0
# host_response_time        0
# host_response_rate        0
# host_acceptance_rate      0
# host_is_superhost         0
# host_thumbnail_url        0
# host_picture_url          0
# host_neighbourhood        0
# host_verifications        0
# host_has_profile_pic      0
# host_identity_verified    0
# neighbourhood             0
# neighbourhood_cleansed    0
# property_type             0
# room_type                 0
# bathrooms_text            0
# amenities                 0
# price                     0
# has_availability          0
# calendar_last_scraped     0
# first_review              0
# last_review               0
# ...

# %% [markdown]
# **Eliminación de outliers con Rango Intercuartílico**

# %% [markdown]
# Se utilizo rango intercuantilico ya que te permite encontrar más outliers ya que acota los límites de los datos

# %%
y=dfnum

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                                              1.690170e+18
# scrape_id                                       2.023033e+13
# host_id                                         6.839189e+08
# host_listings_count                             2.850000e+01
# host_total_listings_count                       3.200000e+01
# latitude                                        1.949915e+01
# longitude                                      -9.911735e+01
# accommodates                                    7.000000e+00
# bedrooms                                        3.500000e+00
# beds                                            3.500000e+00
# minimum_nights                                  3.500000e+00
# maximum_nights                                  2.542500e+03
# minimum_minimum_nights                          3.500000e+00
# maximum_minimum_nights                          6.000000e+00
# minimum_maximum_nights                          2.265000e+03
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= dfnum[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#        id  scrape_id  host_id  host_listings_count  host_total_listings_count  \
# 0     NaN        NaN      NaN                  NaN                        NaN
# 1     NaN        NaN      NaN                  NaN                        NaN
# 2     NaN        NaN      NaN                  NaN                        NaN
# 3     NaN        NaN      NaN                  NaN                        NaN
# 4     NaN        NaN      NaN                  NaN                        NaN
# ...    ..        ...      ...                  ...                        ...
# 24219 NaN        NaN      NaN                  NaN                        NaN
# 24220 NaN        NaN      NaN                  NaN                        NaN
# 24221 NaN        NaN      NaN                  NaN                        NaN
# 24222 NaN        NaN      NaN                  NaN                        NaN
# 24223 NaN        NaN      NaN                  NaN                        NaN
#
# ...

# %%
num_iqr= dfnum[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
num_iqr
# Out:
#                        id       scrape_id    host_id  host_listings_count  \
# 0                 2056638  20230329041210   10531228                  3.0
# 1                 2072354  20230329041210   16840050                  3.0
# 2                  696037  20230329041210    3531879                  4.0
# 3                   35797  20230329041210     153786                  1.0
# 4                   44616  20230329041210     196253                 16.0
# ...                   ...             ...        ...                  ...
# 24219  853923589855678923  20230329041210  488030249                  3.0
# 24220  853966732274073000  20230329041210  506816029                  1.0
# 24221  854225071295768399  20230329041210  154670560                  1.0
# 24222  854247693069190865  20230329041210    7799414                 13.0
# 24223  854260329845513725  20230329041210  506864314                  2.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
valores_nulos=num_iqr.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# scrape_id                                          0
# host_id                                            0
# host_listings_count                             3324
# host_total_listings_count                       3453
# latitude                                        1490
# longitude                                       2594
# accommodates                                    1090
# bedrooms                                         640
# beds                                            2347
# minimum_nights                                  3195
# maximum_nights                                     1
# minimum_minimum_nights                          3082
# maximum_minimum_nights                          1895
# minimum_maximum_nights                             5
# maximum_maximum_nights                             6
# minimum_nights_avg_ntm                          1929
# maximum_nights_avg_ntm                             6
# ...

# %%
num_iqr=num_iqr.fillna(round(num_iqr.mean(),1))
num_iqr
# Out:
#                        id       scrape_id    host_id  host_listings_count  \
# 0                 2056638  20230329041210   10531228                  3.0
# 1                 2072354  20230329041210   16840050                  3.0
# 2                  696037  20230329041210    3531879                  4.0
# 3                   35797  20230329041210     153786                  1.0
# 4                   44616  20230329041210     196253                 16.0
# ...                   ...             ...        ...                  ...
# 24219  853923589855678923  20230329041210  488030249                  3.0
# 24220  853966732274073000  20230329041210  506816029                  1.0
# 24221  854225071295768399  20230329041210  154670560                  1.0
# 24222  854247693069190865  20230329041210    7799414                 13.0
# 24223  854260329845513725  20230329041210  506864314                  2.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
valores_nulos=num_iqr.isnull().sum()
valores_nulos
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# ...

# %%
df_limpio= pd.concat([num_iqr, dfobj], axis=1)
df_limpio
# Out:
#                        id       scrape_id    host_id  host_listings_count  \
# 0                 2056638  20230329041210   10531228                  3.0
# 1                 2072354  20230329041210   16840050                  3.0
# 2                  696037  20230329041210    3531879                  4.0
# 3                   35797  20230329041210     153786                  1.0
# 4                   44616  20230329041210     196253                 16.0
# ...                   ...             ...        ...                  ...
# 24219  853923589855678923  20230329041210  488030249                  3.0
# 24220  853966732274073000  20230329041210  506816029                  1.0
# 24221  854225071295768399  20230329041210  154670560                  1.0
# 24222  854247693069190865  20230329041210    7799414                 13.0
# 24223  854260329845513725  20230329041210  506864314                  2.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
#Convertir DataFrame a CSV
df_limpio.to_csv("DatosMéxico_limpios.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("DatosMéxico_limpios.csv")
