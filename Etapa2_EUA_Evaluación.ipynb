# %% [markdown]
# <a href="https://colab.research.google.com/github/caroSF1/Evaluaci-n/blob/main/Etapa2_EUA_Evaluaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Evaluación Etapa 2**
# ## **Carolina Solis Flores**
# ## **A01708072**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("DatosEUA_limpios.csv",encoding='unicode_escape')

# %% [markdown]
# **a) host_ acceptance_rate> 50%**

# %%
filtro1=df[df['host_acceptance_rate'] > 50]
filtro1
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 0              0       958.0  2.020000e+13       1169.0                  1.0
# 1              1      5858.0  2.020000e+13       8904.0                  2.0
# 2              2      8142.0  2.020000e+13      21994.0                 13.0
# 4              4      8739.0  2.020000e+13       7149.0                  2.0
# 5              5    142177.0  2.020000e+13     656263.0                  1.0
# ...          ...         ...           ...          ...                  ...
# 6929        6929  27790615.3  2.020000e+13  226555948.0                  5.3
# 6930        6930  27790615.3  2.020000e+13  286802480.0                  6.0
# 6931        6931  27790615.3  2.020000e+13   87507815.4                  9.0
# 6932        6932  27790615.3  2.020000e+13   87507815.4                  1.0
# 6933        6933  27790615.3  2.020000e+13   87507815.4                  1.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro1.to_csv("Etapa2_filtroa_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroa_EUA.csv")

# %% [markdown]
# **b) sólo los registros con categoría "superhost"**

# %%
filtro2=df[df["host_is_superhost"] == "t"]
filtro2
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 0              0       958.0  2.020000e+13       1169.0                  1.0
# 4              4      8739.0  2.020000e+13       7149.0                  2.0
# 7              7     10537.0  2.020000e+13      36752.0                  2.0
# 8              8    491867.0  2.020000e+13     969518.0                  2.0
# 9              9    144242.0  2.020000e+13     699215.0                  2.0
# ...          ...         ...           ...          ...                  ...
# 6913        6913  27790615.3  2.020000e+13   36046172.0                  2.0
# 6918        6918  27790615.3  2.020000e+13  375566645.0                 23.0
# 6919        6919  27790615.3  2.020000e+13     330231.0                 10.0
# 6923        6923  27790615.3  2.020000e+13    4452428.0                  3.0
# 6929        6929  27790615.3  2.020000e+13  226555948.0                  5.3
#
# ...

# %%
#Convertir DataFrame a CSV
filtro2.to_csv("Etapa2_filtrob_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrob_EUA.csv")

# %% [markdown]
# c) Los registros que no hallan verificado identidad " not identity_verified"

# %%
filtro3 = df[df["host_identity_verified"] == "f"]
filtro3
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 6              6    490931.0  2.020000e+13    1269188.0                  1.0
# 28            28     18231.0  2.020000e+13      70224.0                  1.0
# 38            38    193292.0  2.020000e+13     937281.0                  1.0
# 39            39    201313.0  2.020000e+13     984585.0                  1.0
# 71            71    231129.0  2.020000e+13    1208533.0                  5.0
# ...          ...         ...           ...          ...                  ...
# 6885        6885  27790615.3  2.020000e+13  157999191.0                 24.0
# 6905        6905  27790615.3  2.020000e+13  240202942.0                  2.0
# 6931        6931  27790615.3  2.020000e+13   87507815.4                  9.0
# 6932        6932  27790615.3  2.020000e+13   87507815.4                  1.0
# 6933        6933  27790615.3  2.020000e+13   87507815.4                  1.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro3.to_csv("Etapa2_filtroc_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroc_EUA.csv")

# %% [markdown]
# d) Los registro cuyo property_type = "Private room" y "Hotel room"

# %%
filtro4 = df[(df["property_type"] == 'Private room') | (df["property_type"] == "Hotel room")]
filtro4
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 7              7     10537.0  2.020000e+13      36752.0                  2.0
# 1575        1575  14305759.0  2.020000e+13   29483318.0                  3.0
# 2049        2049  20957462.0  2.020000e+13  150732464.0                  7.0
# 4014        4014  43477461.0  2.020000e+13  150732464.0                  7.0
#
#       host_total_listings_count  latitude  longitude  accommodates  bedrooms  \
# 7                           3.0  37.71750 -122.39698             2       1.0
# 1575                        3.0  37.75145 -122.40719             2       1.0
# 2049                        9.0  37.79586 -122.41915             2       1.6
# 4014                        9.0  37.79525 -122.41931             1       1.6
#
#       ...     room_type    bathrooms_text  \
# 7     ...  Private room  1.5 shared baths
# 1575  ...  Private room     1 shared bath
# 2049  ...  Private room    1 private bath
# ...

# %%
#Convertir DataFrame a CSV
filtro4.to_csv("Etapa2_filtrod_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrod_EUA.csv")

# %% [markdown]
# e) Los registros que cuenten con bathroom > 1

# %%
filtro5= df[~(df["bathrooms_text"] == '1 bath')  & ~(df["bathrooms_text"] == "1 private bath")]
filtro5
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 2              2      8142.0  2.020000e+13      21994.0                 13.0
# 3              3      8339.0  2.020000e+13      24215.0                  2.0
# 7              7     10537.0  2.020000e+13      36752.0                  2.0
# 8              8    491867.0  2.020000e+13     969518.0                  2.0
# 9              9    144242.0  2.020000e+13     699215.0                  2.0
# ...          ...         ...           ...          ...                  ...
# 6926        6926  27790615.3  2.020000e+13  222540569.0                  7.0
# 6929        6929  27790615.3  2.020000e+13  226555948.0                  5.3
# 6930        6930  27790615.3  2.020000e+13  286802480.0                  6.0
# 6933        6933  27790615.3  2.020000e+13   87507815.4                  1.0
# 6934        6934  27790615.3  2.020000e+13   87507815.4                  3.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro5.to_csv("Etapa2_filtroe.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroe.csv")

# %% [markdown]
# f) Los registros cuyo precio sea mayor de $10,000 y que sean de tipo "Entire home"

# %%
filtro6 = df[(df["price"] > 10000) & (df["room_type"] == "Entire home/apt")]
filtro6
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id     host_id  host_listings_count  \
# 5759        5759  27790615.3  2.020000e+13  32878131.0                  3.0
# 6490        6490  27790615.3  2.020000e+13  91333416.0                 32.0
#
#       host_total_listings_count   latitude  longitude  accommodates  bedrooms  \
# 5759                        6.0  37.732590 -122.43337             4       1.0
# 6490                       50.0  37.781091 -122.47233             4       2.0
#
#       ...        room_type  bathrooms_text  \
# 5759  ...  Entire home/apt          1 bath
# 6490  ...  Entire home/apt          1 bath
#
#                                               amenities  price  \
# 5759  ["Carbon monoxide alarm", "Security cameras on...  14000
# 6490  ["Carbon monoxide alarm", "Hangers", "Iron", "...  25000
#
#       has_availability  calendar_last_scraped  first_review  last_review  \
# 5759                 t               06/03/23      24/08/22     15/11/22
# ...

# %%
#Convertir DataFrame a CSV
filtro6.to_csv("Etapa2_filtrof_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrof_EUA.csv")

# %% [markdown]
# g) Los registros cuyo review_scores_cleanliness > 4.5

# %%
filtro7 = df[df['review_scores_cleanliness'] > 4.5]
filtro7
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id     host_id  host_listings_count  \
# 0              0       958.0  2.020000e+13      1169.0                  1.0
# 1              1      5858.0  2.020000e+13      8904.0                  2.0
# 2              2      8142.0  2.020000e+13     21994.0                 13.0
# 3              3      8339.0  2.020000e+13     24215.0                  2.0
# 4              4      8739.0  2.020000e+13      7149.0                  2.0
# ...          ...         ...           ...         ...                  ...
# 6931        6931  27790615.3  2.020000e+13  87507815.4                  9.0
# 6932        6932  27790615.3  2.020000e+13  87507815.4                  1.0
# 6933        6933  27790615.3  2.020000e+13  87507815.4                  1.0
# 6934        6934  27790615.3  2.020000e+13  87507815.4                  3.0
# 6935        6935  27790615.3  2.020000e+13   4836128.0                  2.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro7.to_csv("Etapa2_filtrog_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrog_EUA.csv")

# %% [markdown]
# h) Los registros cuyo review_scores_value > 4.9

# %%
filtro8 = df[df['review_scores_value'] > 4.9]
filtro8
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 9              9    144242.0  2.020000e+13     699215.0                  2.0
# 24            24    149108.0  2.020000e+13     719538.0                  2.0
# 26            26     12522.0  2.020000e+13      18431.0                  1.0
# 46            46    530857.0  2.020000e+13    2607120.0                  2.0
# 53            53    561602.0  2.020000e+13    2760904.0                  1.0
# ...          ...         ...           ...          ...                  ...
# 6920        6920  27790615.3  2.020000e+13  407298390.0                  9.0
# 6924        6924  27790615.3  2.020000e+13  222540569.0                  7.0
# 6925        6925  27790615.3  2.020000e+13  222540569.0                  7.0
# 6927        6927  27790615.3  2.020000e+13   87507815.4                 32.0
# 6932        6932  27790615.3  2.020000e+13   87507815.4                  1.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro8.to_csv("Etapa2_filtroh_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroh_EUA.csv")

# %% [markdown]
# i) Los registros cuya availability_365<100

# %%
filtro9=df[df['availability_365'] < 100]
filtro9
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id      host_id  host_listings_count  \
# 5              5    142177.0  2.020000e+13     656263.0                  1.0
# 8              8    491867.0  2.020000e+13     969518.0                  2.0
# 9              9    144242.0  2.020000e+13     699215.0                  2.0
# 11            11    144978.0  2.020000e+13     216682.0                  9.0
# 15            15    501770.0  2.020000e+13    2475480.0                  5.0
# ...          ...         ...           ...          ...                  ...
# 6913        6913  27790615.3  2.020000e+13   36046172.0                  2.0
# 6917        6917  27790615.3  2.020000e+13   45555637.0                  1.0
# 6918        6918  27790615.3  2.020000e+13  375566645.0                 23.0
# 6923        6923  27790615.3  2.020000e+13    4452428.0                  3.0
# 6931        6931  27790615.3  2.020000e+13   87507815.4                  9.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro9.to_csv("Etapa2_filtroi_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroi_EUA.csv")

# %% [markdown]
# j) Los registros cuya host_ response_time sea "within an hour"

# %%
filtro10 = df[df["host_response_time"] == "within an hour"]
filtro10
# Out:
#       Unnamed: 0    Ã¯Â»Â¿id     scrape_id     host_id  host_listings_count  \
# 0              0       958.0  2.020000e+13      1169.0                  1.0
# 2              2      8142.0  2.020000e+13     21994.0                 13.0
# 4              4      8739.0  2.020000e+13      7149.0                  2.0
# 5              5    142177.0  2.020000e+13    656263.0                  1.0
# 12            12    493889.0  2.020000e+13   2439917.0                  2.0
# ...          ...         ...           ...         ...                  ...
# 6931        6931  27790615.3  2.020000e+13  87507815.4                  9.0
# 6932        6932  27790615.3  2.020000e+13  87507815.4                  1.0
# 6933        6933  27790615.3  2.020000e+13  87507815.4                  1.0
# 6934        6934  27790615.3  2.020000e+13  87507815.4                  3.0
# 6935        6935  27790615.3  2.020000e+13   4836128.0                  2.0
#
# ...

# %%
#Convertir DataFrame a CSV
filtro10.to_csv("Etapa2_filtroj_EUA.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroj_EUA.csv")
