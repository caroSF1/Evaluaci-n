# %% [markdown]
# <a href="https://colab.research.google.com/github/caroSF1/Evaluaci-n/blob/main/Espa%C3%B1a_Etapa3_Evaluaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Evaluación Etapa 3:  Extracción de Características y Visualización de DATOS España**
# ## **Carolina Solis Flores**
# ## **A01708072**

# %%
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
df = pd.read_csv("DatosEspaña_limpios.csv",encoding='unicode_escape')

# %% [markdown]
# ## **Análisis univariado**

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4421 entries, 0 to 4420
# Data columns (total 73 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    4421 non-null   object
#  1   id                                            4421 non-null   object
#  2   scrape_id                                     4421 non-null   object
#  3   host_id                                       4421 non-null   object
#  4   host_listings_count                           4421 non-null   object
#  5   host_total_listings_count                     4421 non-null   object
#  6   latitude                                      4421 non-null   object
#  7   longitude                                     4421 non-null   object
#  8   accommodates                                  4421 non-null   object
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
df.head()
# Out:
#   Unnamed: 0       id    scrape_id  host_id host_listings_count  \
# 0          0    14551  2.02303E+13    57237                   1
# 1          1  1205757  2.02303E+13  6586355                   1
# 2          2  1212820  2.02303E+13  6620645                   2
# 3          3   751638  2.02303E+13  3680160                   6
# 4          4    41342  2.02303E+13   180072                   2
#
#   host_total_listings_count  latitude longitude accommodates bedrooms  ...  \
# 0                         5   41.9965   2.83646            2        1  ...
# 1                         1  41.79304   2.77412            2        1  ...
# 2                         3  42.11284    3.1667            4        1  ...
# 3                         6  42.36958    2.9803            2        1  ...
# 4                         3  42.34655   3.20463            4        1  ...
#
#          room_type    bathrooms_text  \
# 0     Private room    1 private bath
# 1     Private room  1.5 shared baths
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df)
# Out:
#      Unnamed: 0  frequency  percentage  cumulative_perc
# 0             0          1    0.000226         0.000226
# 1          2945          1    0.000226         0.000452
# 2          2951          1    0.000226         0.000679
# 3          2950          1    0.000226         0.000905
# 4          2949          1    0.000226         0.001131
# ...         ...        ...         ...              ...
# 4416       1478          1    0.000226         0.999095
# 4417       1479          1    0.000226         0.999321
# 4418       1480          1    0.000226         0.999548
# 4419       1481          1    0.000226         0.999774
# 4420       4419          1    0.000226         1.000000
#
# [4421 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#             id  frequency  percentage  cumulative_perc
# 0        14551          1    0.000226         0.000226
# 1     16682425          1    0.000226         0.000452
# ...

# %% [markdown]
# ## **A)host_response_time**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       2736    0.618865         0.619285
# 1  within a few hours        913    0.206514         0.825939
# 2        within a day        620    0.140240         0.966274
# 3  a few days or more        149    0.033703         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>110]
Filtro
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       2736    0.618865         0.619285
# 1  within a few hours        913    0.206514         0.825939
# 2        within a day        620    0.140240         0.966274
# 3  a few days or more        149    0.033703         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour           2736    0.618865         0.619285
# within a few hours        913    0.206514         0.825939
# within a day              620    0.140240         0.966274
# a few days or more        149    0.033703         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tiempo de respuesta del host')
plt.xlabel('Tiempo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## **C) host_identity_verified**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(df['host_identity_verified'])
table2
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       3894    0.880796         0.881394
# 1                      f        524    0.118525         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table2[table2['frequency']>1]
Filtro
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       3894    0.880796         0.881394
# 1                      f        524    0.118525         1.000000

# %%
Filtro_index2= Filtro.set_index('host_identity_verified')
Filtro_index2
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                            3894    0.880796         0.881394
# f                             524    0.118525         1.000000

# %%
Filtro_index2["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title("Identidad del host verificada")
# Out:
# Text(0.5, 1.0, 'Identidad del host verificada')

# %% [markdown]
# ## **D) property_type**

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(df['property_type'])
table3
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       2199    0.497399         0.497737
# 1                          Entire home       1008    0.228003         0.725894
# 2                         Entire condo        269    0.060846         0.786781
# 3                         Entire villa        234    0.052929         0.839746
# 4                     Entire townhouse        137    0.030988         0.870756
# 5                       Entire cottage        120    0.027143         0.897918
# 6                          Entire loft         60    0.013572         0.911498
# 7                 Private room in home         49    0.011083         0.922589
# 8          Private room in rental unit         44    0.009952         0.932549
# 9    Private room in bed and breakfast         35    0.007917         0.940471
# 10           Entire serviced apartment         33    0.007464         0.947940
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>100]
Filtro
# Out:
#         property_type  frequency  percentage  cumulative_perc
# 0  Entire rental unit       2199    0.497399         0.497737
# 1         Entire home       1008    0.228003         0.725894
# 2        Entire condo        269    0.060846         0.786781
# 3        Entire villa        234    0.052929         0.839746
# 4    Entire townhouse        137    0.030988         0.870756
# 5      Entire cottage        120    0.027143         0.897918

# %%
Filtro_index3= Filtro.set_index('property_type')
Filtro_index3
# Out:
#                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit       2199    0.497399         0.497737
# Entire home              1008    0.228003         0.725894
# Entire condo              269    0.060846         0.786781
# Entire villa              234    0.052929         0.839746
# Entire townhouse          137    0.030988         0.870756
# Entire cottage            120    0.027143         0.897918

# %%
Filtro_index3.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de propiedades más frecuentes')
plt.xlabel('Tipo de propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## **I) review_scores_location**

# %%
df['review_scores_location'].unique()
# Out:
# array([4.63, 4.69, 4.74, 4.91, 4.79, 4.5 , 4.56, 4.89, 4.81, 4.7 , 4.36,
#        4.93, 4.9 , 4.33, 4.64, 4.8 , 4.4 , 5.  , 4.67, 4.82, 4.84, 4.87,
#        4.95, 4.57, 4.45, 4.78, 4.88, 4.75, 4.94, 4.38, 4.71, 4.97, 4.92,
#        4.73, 4.86, 4.54, 4.96, 4.51, 4.76, 4.85, 4.46, 4.77, 4.31, 4.55,
#        4.61, 4.83, 4.72, 4.49, 4.68, 4.47, 4.66, 4.59, 4.53, 4.43, 4.98,
#        4.52, 4.37, 4.99, 4.44, 4.58, 4.62, 4.6 , 4.35, 4.65, 4.3 , 4.41,
#        4.48, 4.39, 4.34, 4.42,  nan, 4.32])

# %%
df.review_scores_location= df.review_scores_location.astype(str)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(df['review_scores_location'])
table4
# Out:
#    review_scores_location  frequency  percentage  cumulative_perc
# 0                     5.0        875    0.197919         0.197919
# 1                     4.8        453    0.102466         0.300385
# 2                     4.7        427    0.096584         0.396969
# 3                     4.5        164    0.037096         0.434065
# 4                    4.67        158    0.035739         0.469803
# ..                    ...        ...         ...              ...
# 67                    4.3          2    0.000452         0.998417
# 68                   4.31          2    0.000452         0.998869
# 69                   4.34          2    0.000452         0.999321
# 70                   4.42          2    0.000452         0.999774
# 71                    nan          1    0.000226         1.000000
#
# [72 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>115]
Filtro
# Out:
#   review_scores_location  frequency  percentage  cumulative_perc
# 0                    5.0        875    0.197919         0.197919
# 1                    4.8        453    0.102466         0.300385
# 2                    4.7        427    0.096584         0.396969
# 3                    4.5        164    0.037096         0.434065
# 4                   4.67        158    0.035739         0.469803

# %%
Filtro_index4= Filtro.set_index('review_scores_location')
Filtro_index4
# Out:
#                         frequency  percentage  cumulative_perc
# review_scores_location
# 5.0                           875    0.197919         0.197919
# 4.8                           453    0.102466         0.300385
# 4.7                           427    0.096584         0.396969
# 4.5                           164    0.037096         0.434065
# 4.67                          158    0.035739         0.469803

# %%
Filtro_index4.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Review/puntuación locación')
plt.xlabel('Puntuación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## **G) review_scores_cleanliness**

# %%
df['review_scores_cleanliness'].unique()
# Out:
# array([4.94, 4.85, 4.31, 4.5 , 4.82, 4.69, 4.79, 4.78, 4.73, 4.38, 4.95,
#        4.88, 4.55, 4.  , 5.  , 4.76, 4.96, 4.6 , 4.4 , 4.3 , 4.65, 4.84,
#        4.87, 4.72, 4.81, 4.91, 4.64, 4.26, 4.8 , 4.67, 4.74, 4.45, 4.9 ,
#        4.71, 4.43, 4.75, 4.48, 4.54, 4.68, 4.57, 4.77, 4.51, 4.46, 4.59,
#        4.66, 4.93, 4.13, 4.52, 4.58, 4.15, 4.61, 4.33, 4.41, 4.7 , 4.19,
#        4.53, 4.39, 4.92, 4.23, 4.2 , 4.56, 4.89, 4.97, 4.83, 4.98, 4.86,
#        4.1 , 4.17, 4.29, 4.06, 4.09, 4.63, 4.42, 4.25, 4.44, 4.47, 4.27,
#        4.16, 3.92, 4.36, 4.07, 3.95, 4.28, 4.21, 4.22, 4.62, 4.32, 4.11,
#        4.35, 4.49, 4.99, 4.14, 4.04, 4.37, 3.93, 4.34, 4.24, 4.18, 4.08,
#        4.12, 4.02,  nan, 4.05, 3.97, 3.98, 3.96, 3.94])

# %%
df.review_scores_cleanliness= df.review_scores_cleanliness.astype(str)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(df['review_scores_cleanliness'])
table5
# Out:
#     review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0                         5.0        618    0.139787         0.139787
# 1                         4.5        551    0.124632         0.264420
# 2                         4.6        355    0.080299         0.344718
# 3                         4.0        223    0.050441         0.395159
# 4                        4.67        144    0.032572         0.427731
# ..                        ...        ...         ...              ...
# 102                      3.94          2    0.000452         0.999095
# 103                       nan          1    0.000226         0.999321
# 104                      3.97          1    0.000226         0.999548
# 105                      3.98          1    0.000226         0.999774
# 106                      3.96          1    0.000226         1.000000
#
# [107 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>140]
Filtro
# Out:
#   review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0                       5.0        618    0.139787         0.139787
# 1                       4.5        551    0.124632         0.264420
# 2                       4.6        355    0.080299         0.344718
# 3                       4.0        223    0.050441         0.395159
# 4                      4.67        144    0.032572         0.427731

# %%
Filtro_index5= Filtro.set_index('review_scores_cleanliness')
Filtro_index5
# Out:
#                            frequency  percentage  cumulative_perc
# review_scores_cleanliness
# 5.0                              618    0.139787         0.139787
# 4.5                              551    0.124632         0.264420
# 4.6                              355    0.080299         0.344718
# 4.0                              223    0.050441         0.395159
# 4.67                             144    0.032572         0.427731

# %%
Filtro_index5["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title("Puntuación/review limpieza")
# Out:
# Text(0.5, 1.0, 'Puntuación/review limpieza')
