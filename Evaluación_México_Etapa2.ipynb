# %% [markdown]
# <a href="https://colab.research.google.com/github/caroSF1/Evaluaci-n/blob/main/Evaluaci%C3%B3n_M%C3%A9xico_Etapa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Evaluación Etapa 2* México*
# ## **Carolina Solis Flores**
# ## **A01708072**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("DatosMéxico_limpios.csv", low_memory=False)

# %% [markdown]
# **a) host_ acceptance_rate> 50%**

# %%
filtro1=df[df['host_acceptance_rate'] > 50]
filtro1
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 1             1.0      2072354  2.02303E+13   16840050                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# ...           ...          ...          ...        ...                 ...
# 24221     24219.0  8.53924E+17  2.02303E+13  488030249                   3
# 24222     24220.0  8.53967E+17  2.02303E+13  506816029                   1
# 24223     24221.0  8.54225E+17  2.02303E+13  154670560                   1
# 24224     24222.0  8.54248E+17  2.02303E+13    7799414                  13
# 24225     24223.0   8.5426E+17  2.02303E+13  506864314                   2
#
# ...

# %%
#Convertir DataFrame a CSV
filtro1.to_csv("Etapa2_filtroa_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroa_México.csv")

# %% [markdown]
# **b) sólo los registros con categoría "superhost"**

# %%
filtro2=df[df["host_is_superhost"] == "t"]
filtro2
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 2             2.0       696037  2.02303E+13    3531879                   4
# 6             6.0        56074  2.02303E+13     265650                   2
# 7             7.0        61792  2.02303E+13     299558                   2
# 8             8.0       704779  2.02303E+13    2872228                  13
# 9             9.0       728372  2.02303E+13    3777702                   6
# ...           ...          ...          ...        ...                 ...
# 24173     24171.0  8.55775E+17  2.02303E+13  333035396                 5.3
# 24181     24179.0  8.56003E+17  2.02303E+13   10764020                 5.3
# 24193     24191.0  8.56174E+17  2.02303E+13  420886866                   2
# 24205     24203.0    8.565E+17  2.02303E+13    8905097                 5.3
# 24224     24222.0  8.54248E+17  2.02303E+13    7799414                  13
#
# ...

# %%
#Convertir DataFrame a CSV
filtro2.to_csv("Etapa2_filtrob_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrob_México.csv")

# %% [markdown]
# c) Los registros que no hallan verificado identidad " not identity_verified"

# %%
filtro3 = df[df["host_identity_verified"] == "f"]
filtro3
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 21           21.0       131610  2.02303E+13     647454                   3
# 61           61.0       276504  2.02303E+13    1444589                   1
# 68           68.0       291804  2.02303E+13    1511568                   1
# 70           70.0       298873  2.02303E+13    1539548                   1
# ...           ...          ...          ...        ...                 ...
# 23697     23695.0  8.41965E+17  2.02303E+13   13667851                   2
# 23875     23873.0  8.48589E+17  2.02303E+13  487627497                  17
# 23967     23965.0  8.49311E+17  2.02303E+13  408076348                   3
# 23968     23966.0  8.49316E+17  2.02303E+13  408076348                   3
# 23974     23972.0  8.49319E+17  2.02303E+13  408076348                   3
#
# ...

# %%
#Convertir DataFrame a CSV
filtro3.to_csv("Etapa2_filtroc_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroc_México.csv")

# %% [markdown]
# d) Los registro cuyo property_type = "Private room" y "Hotel room"

# %%
filtro4 = df[(df["property_type"] == 'Private room') | (df["property_type"] == "Hotel room")]
filtro4
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 21           21.0       131610  2.02303E+13     647454                   3
# 1062       1062.0     12271259  2.02303E+13    2556582                   1
# 2670       2670.0     19639981  2.02303E+13  136125882                   1
# 2805       2805.0     20089283  2.02303E+13  142841816                   1
# 3065       3065.0     21067896  2.02303E+13  151816281                   2
# 3257       3257.0     21765818  2.02303E+13  158580118                   1
# 3359       3359.0     22230184  2.02303E+13   93911392                  28
# 3372       3372.0     22247072  2.02303E+13   93911392                  28
# 3455       3455.0     22340146  2.02303E+13  115584349                   3
# 3571       3571.0     23026367  2.02303E+13  170856978                   1
# 3605       3605.0     23100799  2.02303E+13  103716258                   1
# ...

# %%
#Convertir DataFrame a CSV
filtro4.to_csv("Etapa2_filtrod_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrod_México.csv")

# %% [markdown]
# e) Los registros que cuenten con bathroom > 1

# %%
filtro5= df[~(df["bathrooms_text"] == '1 bath')  & ~(df["bathrooms_text"] == "1 private bath")]
filtro5
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 4             4.0        44616  2.02303E+13     196253                  16
# 5             5.0      2075738  2.02303E+13    2339771                   1
# 7             7.0        61792  2.02303E+13     299558                   2
# ...           ...          ...          ...        ...                 ...
# 24208     24206.0  8.56513E+17  2.02303E+13  445250346                   4
# 24212     24210.0  8.53691E+17  2.02303E+13  155903047                   1
# 24215     24213.0  8.53708E+17  2.02303E+13  506768013                   1
# 24220     24218.0  8.53922E+17  2.02303E+13  506810572                   4
# 24223     24221.0  8.54225E+17  2.02303E+13  154670560                   1
#
# ...

# %%
#Convertir DataFrame a CSV
filtro5.to_csv("Etapa2_filtroe_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroe_México.csv")

# %% [markdown]
# f) Los registros cuyo precio sea mayor de $10,000 y que sean de tipo "Entire home"

# %%
filtro6 = df[(df["price"] > 10000) & (df["room_type"] == "Entire home/apt")]
filtro6
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 4             4.0        44616  2.02303E+13     196253                  16
# 37           37.0       187030  2.02303E+13     899360                   6
# 418         418.0      6041044  2.02303E+13    7529413                   1
# 544         544.0      6871835  2.02303E+13   36014559                   1
# 958         958.0      9946549  2.02303E+13   51117526                   1
# ...           ...          ...          ...        ...                 ...
# 23252     23250.0  8.29075E+17  2.02303E+13  104953556                 5.3
# 23470     23468.0  8.38378E+17  2.02303E+13  503547027                   1
# 23693     23691.0  8.43086E+17  2.02303E+13    8995867                  17
# 24105     24103.0  8.53048E+17  2.02303E+13   10764020                 5.3
# 24194     24192.0  8.56441E+17  2.02303E+13  114903513                   2
#
# ...

# %%
#Convertir DataFrame a CSV
filtro6.to_csv("Etapa2_filtrof_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrof_México.csv")

# %% [markdown]
# g) Los registros cuyo review_scores_cleanliness > 4.5

# %%
filtro7 = df[df['review_scores_cleanliness'] > 4.5]
filtro7
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 0             0.0      2056638  2.02303E+13   10531228                   3
# 1             1.0      2072354  2.02303E+13   16840050                   3
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# ...           ...          ...          ...        ...                 ...
# 24221     24219.0  8.53924E+17  2.02303E+13  488030249                   3
# 24222     24220.0  8.53967E+17  2.02303E+13  506816029                   1
# 24223     24221.0  8.54225E+17  2.02303E+13  154670560                   1
# 24224     24222.0  8.54248E+17  2.02303E+13    7799414                  13
# 24225     24223.0   8.5426E+17  2.02303E+13  506864314                   2
#
# ...

# %%
#Convertir DataFrame a CSV
filtro7.to_csv("Etapa2_filtrog_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtrog_México.csv")

# %% [markdown]
# h) Los registros cuyo review_scores_value > 4.9

# %%
filtro8 = df[df['review_scores_value'] > 4.9]
filtro8
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 10           10.0      2083241  2.02303E+13    8282570                   7
# 11           11.0        67703  2.02303E+13     334451                   3
# 13           13.0        70644  2.02303E+13     212109                   3
# 24           24.0       783080  2.02303E+13    1767559                   3
# 26           26.0      2118573  2.02303E+13   10802698                   3
# ...           ...          ...          ...        ...                 ...
# 24059     24057.0  8.52768E+17  2.02303E+13   10059555                   2
# 24060     24058.0  8.52783E+17  2.02303E+13  263823796                   3
# 24111     24109.0  8.53066E+17  2.02303E+13  406773068                   1
# 24129     24127.0  8.53139E+17  2.02303E+13  257870736                   1
# 24190     24188.0  8.56097E+17  2.02303E+13  484538652                  12
#
# ...

# %%
#Convertir DataFrame a CSV
filtro8.to_csv("Etapa2_filtroh_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroh_México.csv")

# %% [markdown]
# i) Los registros cuya availability_365<100

# %%
df['availability_365'].unique()
# Out:
# array(['324', '346', '87', '363', '357', '240', '144', '168', '156',
#        '270', '153', '362', '358', '145', '340', '350', '284', '365',
#        '317', '303', '88', '280', '341', '336', '304', '194', '295',
#        '354', '328', '214', '356', '155', '197', '0', '26', '305', '348',
#        '307', '269', '361', '313', '211', '332', '326', '272', '247',
#        '127', '266', '330', '287', '334', '296', '188', '312', '167',
#        '162', '288', '120', '179', '331', '253', '90', '114', '184',
#        '364', '292', '344', '142', '207', '360', '80', '137', '2', '72',
#        '30', '234', '298', '11', '121', '327', '333', '116', '48', '250',
#        '84', '256', '318', '252', '347', '204', '329', '176', '209',
#        '139', '16', '152', '335', '276', '200', '146', '62', '178', '81',
#        '181', '238', '251', '159', '172', '325', '75', '337', '193',
#        '134', '149', '355', '322', '248', '136', '174', '262', '51',
# ...

# %%
df.availability_365 = df.availability_365.astype(int)

# %%
#Se sustituye con cero, ya que no se sabe cual era el valor real del dato. 
df.availability_365 = df.availability_365.replace({'f':'0'}, regex=False)

# %%
filtro9=df[df['availability_365'] < 100]
filtro9
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 2             2.0       696037  2.02303E+13    3531879                   4
# 21           21.0       131610  2.02303E+13     647454                   3
# 26           26.0      2118573  2.02303E+13   10802698                   3
# 37           37.0       187030  2.02303E+13     899360                   6
# 38           38.0       187745  2.02303E+13     899360                   6
# ...           ...          ...          ...        ...                 ...
# 24161     24159.0  8.55707E+17  2.02303E+13    3394561                   2
# 24167     24165.0  8.57303E+17  2.02303E+13  227002676                 5.3
# 24172     24170.0  8.57303E+17  2.02303E+13  227002676                 5.3
# 24188     24186.0  8.56096E+17  2.02303E+13    2086889                   1
# 24195     24193.0  8.56446E+17  2.02303E+13    3240358                   3
#
# ...

# %%
#Convertir DataFrame a CSV
filtro9.to_csv("Etapa2_filtroi_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroi_México.csv")

# %% [markdown]
# j) Los registros cuya host_ response_time sea "within an hour"

# %%
filtro10 = df[df["host_response_time"] == "within an hour"]
filtro10
# Out:
#        Unnamed: 0           id    scrape_id    host_id host_listings_count  \
# 2             2.0       696037  2.02303E+13    3531879                   4
# 3             3.0        35797  2.02303E+13     153786                   1
# 4             4.0        44616  2.02303E+13     196253                  16
# 6             6.0        56074  2.02303E+13     265650                   2
# 7             7.0        61792  2.02303E+13     299558                   2
# ...           ...          ...          ...        ...                 ...
# 24221     24219.0  8.53924E+17  2.02303E+13  488030249                   3
# 24222     24220.0  8.53967E+17  2.02303E+13  506816029                   1
# 24223     24221.0  8.54225E+17  2.02303E+13  154670560                   1
# 24224     24222.0  8.54248E+17  2.02303E+13    7799414                  13
# 24225     24223.0   8.5426E+17  2.02303E+13  506864314                   2
#
# ...

# %%
#Convertir DataFrame a CSV
filtro10.to_csv("Etapa2_filtroj_México.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Etapa2_filtroj_México.csv")
